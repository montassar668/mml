# %% [markdown]
# <a href="https://colab.research.google.com/github/montassar668/mml/blob/main/TPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importation des bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importation de fichier CSV Test_V2 et creation de dataframe df_test
#from google.colab import files
#data_to_load = files.upload()
#import io
#df_test = pd.read_csv(io.BytesIO(data_to_load['Test_v2.csv']))
df_test=pd.read_csv('/content/drive/MyDrive/Data Science colab/Test_v2.csv')

# %%
#Importation de fichier CSV Train_V2 et creation de dataframe df_train
#from google.colab import files
#data_to_load = files.upload()
#import io
#df_Train = pd.read_csv(io.BytesIO(data_to_load['Train_v2.csv']))
df_Train=pd.read_csv('/content/drive/MyDrive/Data Science colab/Train_v2.csv')

# %%
#Affichage de dataframe df_test
df_test
# Out:
#       country  ...                      job_type
# 0       Kenya  ...  Formally employed Government
# 1       Kenya  ...     Formally employed Private
# 2       Kenya  ...          Remittance Dependent
# 3       Kenya  ...          Remittance Dependent
# 4       Kenya  ...          Remittance Dependent
# ...       ...  ...                           ...
# 10081  Uganda  ...                 Self employed
# 10082  Uganda  ...                 Self employed
# 10083  Uganda  ...                  Other Income
# 10084  Uganda  ...                 Self employed
# 10085  Uganda  ...                  Other Income
#
# [10086 rows x 12 columns]

# %%
#Visualisation nombre des female par rapport au nombre male
df_test.gender_of_respondent.value_counts().plot.bar(color='Y')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py:1373: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   return ax.bar(x, y, w, bottom=start, log=log, **kwds)

# %%
#Visualisation de la nature de relation des mombres
df_test.relationship_with_head.value_counts().plot.bar(color='gold')

# %%
#Visualisation de nombre des membres qui possèdent un telephone portable
df_test.cellphone_access.value_counts().plot.bar(color='C')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py:1373: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   return ax.bar(x, y, w, bottom=start, log=log, **kwds)

# %%
#Affichage de dataframe df_train
df_Train
# Out:
#       country  year  ...                  education_level                   job_type
# 0       Kenya  2018  ...              Secondary education              Self employed
# 1       Kenya  2018  ...              No formal education       Government Dependent
# 2       Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3       Kenya  2018  ...                Primary education  Formally employed Private
# 4       Kenya  2018  ...                Primary education        Informally employed
# ...       ...   ...  ...                              ...                        ...
# 23519  Uganda  2018  ...              No formal education               Other Income
# 23520  Uganda  2018  ...              Secondary education               Other Income
# 23521  Uganda  2018  ...                Primary education               Other Income
# 23522  Uganda  2018  ...              Secondary education              Self employed
# ...

# %%
#Visualisation de nombre des membres qui possèdent un compte bancaire
df_Train.bank_account.value_counts().plot.bar(color='lightcoral');

# %%
#vérification de type des colonnes de dataframe df_test
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10086 entries, 0 to 10085
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 10086 non-null  object
#  1   year                    10086 non-null  int64
#  2   uniqueid                10086 non-null  object
#  3   location_type           10086 non-null  object
#  4   cellphone_access        10086 non-null  object
#  5   household_size          10086 non-null  int64
#  6   age_of_respondent       10086 non-null  int64
#  7   gender_of_respondent    10086 non-null  object
#  8   relationship_with_head  10086 non-null  object
#  9   marital_status          10086 non-null  object
#  10  education_level         10086 non-null  object
#  11  job_type                10086 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 945.7+ KB

# %%
#vérification de type des colonnes de dataframe df_Train
df_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
#Grouper le dataframe df_test par sexe du répondant (Male)
df1_test_m = df_test.groupby(by=["gender_of_respondent"]).get_group("Male")
df1_test_m
# Out:
#       country  ...                      job_type
# 0       Kenya  ...  Formally employed Government
# 1       Kenya  ...     Formally employed Private
# 4       Kenya  ...          Remittance Dependent
# 9       Kenya  ...           Farming and Fishing
# 10      Kenya  ...          Remittance Dependent
# ...       ...  ...                           ...
# 10076  Uganda  ...                 Self employed
# 10080  Uganda  ...                 Self employed
# 10082  Uganda  ...                 Self employed
# 10083  Uganda  ...                  Other Income
# 10085  Uganda  ...                  Other Income
#
# [4239 rows x 12 columns]

# %%
#Grouper le dataframe df_test par sexe du répondant (Female)
df1_test_f = df_test.groupby(by=["gender_of_respondent"]).get_group("Female")
df1_test_f
# Out:
#       country  year  ...                  education_level              job_type
# 2       Kenya  2018  ...              No formal education  Remittance Dependent
# 3       Kenya  2018  ...                Primary education  Remittance Dependent
# 5       Kenya  2018  ...                Primary education         Self employed
# 6       Kenya  2018  ...                Primary education   Informally employed
# 7       Kenya  2018  ...  Vocational/Specialised training         Self employed
# ...       ...   ...  ...                              ...                   ...
# 10077  Uganda  2018  ...                Primary education         Self employed
# 10078  Uganda  2018  ...                Primary education         Self employed
# 10079  Uganda  2018  ...              Secondary education          Other Income
# 10081  Uganda  2018  ...                Primary education         Self employed
# 10084  Uganda  2018  ...                Primary education         Self employed
#
# ...

# %%
#Affichage de nombre de ligne et des colonnes de df1_test_m (dataframe grouper par sexe Male)
df1_test_m.shape
# Out:
# (4239, 12)

# %%
#Affichage de nombre de ligne et des colonnes de df1_test_m (dataframe grouper par sexe Female)
df1_test_f.shape
# Out:
# (5847, 12)

# %%
#Tree de dataframe par age
df1_test_m.sort_values(by='age_of_respondent')
# Out:
#         country  year  ...      education_level              job_type
# 10085    Uganda  2018  ...  Secondary education          Other Income
# 6127     Rwanda  2016  ...    Primary education         Self employed
# 3498     Rwanda  2016  ...    Primary education  Remittance Dependent
# 9603     Uganda  2018  ...    Primary education             No Income
# 9061   Tanzania  2017  ...  No formal education   Informally employed
# ...         ...   ...  ...                  ...                   ...
# 102       Kenya  2018  ...  No formal education  Remittance Dependent
# 8790   Tanzania  2017  ...  No formal education  Remittance Dependent
# 3160     Rwanda  2016  ...  No formal education   Farming and Fishing
# 9926     Uganda  2018  ...  No formal education             No Income
# 377       Kenya  2018  ...  No formal education   Farming and Fishing
#
# [4239 rows x 12 columns]

# %%
#Tree de dataframe par age
df1_test_f.sort_values(by='age_of_respondent')
# Out:
#        country  year  ...      education_level              job_type
# 4230    Rwanda  2016  ...  Secondary education   Farming and Fishing
# 7887  Tanzania  2017  ...  Secondary education  Remittance Dependent
# 2580     Kenya  2018  ...    Primary education  Remittance Dependent
# 2582     Kenya  2018  ...    Primary education  Remittance Dependent
# 7861  Tanzania  2017  ...  Secondary education  Remittance Dependent
# ...        ...   ...  ...                  ...                   ...
# 104      Kenya  2018  ...  No formal education  Remittance Dependent
# 2279     Kenya  2018  ...  No formal education          Other Income
# 9110  Tanzania  2017  ...  No formal education             No Income
# 4904    Rwanda  2016  ...  No formal education  Remittance Dependent
# 6594  Tanzania  2017  ...    Primary education  Government Dependent
#
# [5847 rows x 12 columns]

# %%
#Verification d'existance des valeur Null de dataframe df_test
df_test.isnull()
# Out:
#        country   year  uniqueid  ...  marital_status  education_level  job_type
# 0        False  False     False  ...           False            False     False
# 1        False  False     False  ...           False            False     False
# 2        False  False     False  ...           False            False     False
# 3        False  False     False  ...           False            False     False
# 4        False  False     False  ...           False            False     False
# ...        ...    ...       ...  ...             ...              ...       ...
# 10081    False  False     False  ...           False            False     False
# 10082    False  False     False  ...           False            False     False
# 10083    False  False     False  ...           False            False     False
# 10084    False  False     False  ...           False            False     False
# 10085    False  False     False  ...           False            False     False
#
# ...

# %%
#Affichge de la somme des valeur Null de dataframe df_test (dans cette cas il y a aucun valeur Null)
df_test.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
#Verification d'existance des valeur Null de dataframe df_train
df_Train.isnull()
# Out:
#        country   year  uniqueid  ...  marital_status  education_level  job_type
# 0        False  False     False  ...           False            False     False
# 1        False  False     False  ...           False            False     False
# 2        False  False     False  ...           False            False     False
# 3        False  False     False  ...           False            False     False
# 4        False  False     False  ...           False            False     False
# ...        ...    ...       ...  ...             ...              ...       ...
# 23519    False  False     False  ...           False            False     False
# 23520    False  False     False  ...           False            False     False
# 23521    False  False     False  ...           False            False     False
# 23522    False  False     False  ...           False            False     False
# 23523    False  False     False  ...           False            False     False
#
# ...

# %%
#Affichge de la somme des valeur Null de dataframe df_train (dans cette cas il y a aucun valeur Null)
df_Train.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
#Convertire le colonne bank account au format entier (données numériques) en utilisant label encoder from sklearn
from sklearn.preprocessing import LabelEncoder
lc = LabelEncoder()
df_Train['bank_account'] = lc.fit_transform(df_Train['bank_account'])
df_Train
# Out:
#       country  year  ...                  education_level                   job_type
# 0       Kenya  2018  ...              Secondary education              Self employed
# 1       Kenya  2018  ...              No formal education       Government Dependent
# 2       Kenya  2018  ...  Vocational/Specialised training              Self employed
# 3       Kenya  2018  ...                Primary education  Formally employed Private
# 4       Kenya  2018  ...                Primary education        Informally employed
# ...       ...   ...  ...                              ...                        ...
# 23519  Uganda  2018  ...              No formal education               Other Income
# 23520  Uganda  2018  ...              Secondary education               Other Income
# 23521  Uganda  2018  ...                Primary education               Other Income
# 23522  Uganda  2018  ...              Secondary education              Self employed
# ...

# %%
#Ajouter une autre colonne nomée year pour les deux dataframe
df_Train['year_'] = df_Train['year']
df_test['year_'] = df_test['year']

# Convertit les colonnes household_size,age_of_respondent,year en flottant
float_array = df_Train[['household_size', 'age_of_respondent', 'year_']].values.astype(float)
float_array = df_test[['household_size', 'age_of_respondent', 'year_']].values.astype(float)

# %%
# convertir des entités catégorielles en entités numériques
df_Train['country_'] = df_Train['country']
df_test['country_'] = df_test['country']

categ = ['relationship_with_head', 'marital_status', 'education_level', 'job_type', 'country_']

#  transformer une catégorie au format entier en plusieurs colonnes au format binaire
df_Train = pd.get_dummies(df_Train, prefix_sep='_', columns = categ)
df_test = pd.get_dummies(df_test, prefix_sep='_', columns = categ)

# convertir les colonnes (location_type,cellphone_access,gender_of_respondent) de deux dataframes au format entier
df_Train['location_type'] = lc.fit_transform(df_Train['location_type'])
df_Train['cellphone_access'] = lc.fit_transform(df_Train['cellphone_access'])
df_Train['gender_of_respondent'] = lc.fit_transform(df_Train['gender_of_respondent'])

df_test['location_type'] = lc.fit_transform(df_test['location_type'])
df_test['cellphone_access'] = lc.fit_transform(df_test['cellphone_access'])
df_test['gender_of_respondent'] = lc.fit_transform(df_test['gender_of_respondent'])

# %%
#Affichage dataframe df test avec la nouvelle transformation des données
df_test
# Out:
#       country  year  ... country__Tanzania  country__Uganda
# 0       Kenya  2018  ...                 0                0
# 1       Kenya  2018  ...                 0                0
# 2       Kenya  2018  ...                 0                0
# 3       Kenya  2018  ...                 0                0
# 4       Kenya  2018  ...                 0                0
# ...       ...   ...  ...               ...              ...
# 10081  Uganda  2018  ...                 0                1
# 10082  Uganda  2018  ...                 0                1
# 10083  Uganda  2018  ...                 0                1
# 10084  Uganda  2018  ...                 0                1
# 10085  Uganda  2018  ...                 0                1
#
# [10086 rows x 40 columns]

# %%
#Affichage dataframe df train avec la nouvelle transformation des données
df_Train
# Out:
#       country  year  ... country__Tanzania  country__Uganda
# 0       Kenya  2018  ...                 0                0
# 1       Kenya  2018  ...                 0                0
# 2       Kenya  2018  ...                 0                0
# 3       Kenya  2018  ...                 0                0
# 4       Kenya  2018  ...                 0                0
# ...       ...   ...  ...               ...              ...
# 23519  Uganda  2018  ...                 0                1
# 23520  Uganda  2018  ...                 0                1
# 23521  Uganda  2018  ...                 0                1
# 23522  Uganda  2018  ...                 0                1
# 23523  Uganda  2018  ...                 0                1
#
# [23524 rows x 41 columns]

# %%
#préparation de x_train, Y_train et x test
X_train = df_Train.drop(['year', 'uniqueid', 'bank_account', 'country'], axis=1)
y_train = df_Train['bank_account']
X_test = df_test.drop(['year', 'uniqueid', 'country'], axis=1)

# importer MinMaxScaler (pour normaliser variables d'entrée,toutes les entités seront transformées dans la plage [0,1])
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_res = scaler.fit_transform(X_train)
X_test_res = scaler.fit_transform(X_test)

# %%
df_Train
# Out:
#       country  year  ... country__Tanzania  country__Uganda
# 0       Kenya  2018  ...                 0                0
# 1       Kenya  2018  ...                 0                0
# 2       Kenya  2018  ...                 0                0
# 3       Kenya  2018  ...                 0                0
# 4       Kenya  2018  ...                 0                0
# ...       ...   ...  ...               ...              ...
# 23519  Uganda  2018  ...                 0                1
# 23520  Uganda  2018  ...                 0                1
# 23521  Uganda  2018  ...                 0                1
# 23522  Uganda  2018  ...                 0                1
# 23523  Uganda  2018  ...                 0                1
#
# [23524 rows x 41 columns]

# %%
# Divisé données de train et test
from sklearn.model_selection import train_test_split
X_Train, X_val, y_Train, y_val = train_test_split(X_train_res, y_train, stratify = y_train, test_size = 0.2, random_state=42)

# %%
#importer XGBClassifier
from xgboost import XGBClassifier
my_model = XGBClassifier()

# importer GridSearchCV
from sklearn.model_selection import GridSearchCV

# Optimiser les paramètres du modèle
param_grid = {'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
my_model2 = GridSearchCV(my_model, param_grid)
my_model2.fit(X_Train, y_Train)
print(my_model2.best_params_)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Évaluer le modèle
my_model3 = XGBClassifier(min_child_weight = 5, gamma = 0.5, subsample = 0.6, colsample_bytree = 0.6, max_depth = 5)
my_model3.fit(X_Train, y_Train)
y_pred = my_model3.predict(X_val)

# Obtenir le taux d'erreur
print("Error rate of Random Forest classifier: ", 1 - accuracy_score(y_val, y_pred))

# Obtenir la matrice de confusion
confusion_matrix(y_pred, y_val)
# Out:
# Error rate of Random Forest classifier:  0.11052072263549417
# array([[3942,  419],
#        [ 101,  243]])

# %%
#Obtenez le résultat prévu pour les données de test (predicted result)
df_test.bank_account = my_model3.predict(X_test_res)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
# créer un DataFrame pour les nouveau données
df_result = pd.DataFrame({"uniqueid": df_test["uniqueid"] + " x " + df_test["country"],

"bank_account": df_test.bank_account})

# %%
df_result
# Out:
#                      uniqueid  bank_account
# 0       uniqueid_6056 x Kenya             1
# 1       uniqueid_6060 x Kenya             1
# 2       uniqueid_6065 x Kenya             0
# 3       uniqueid_6072 x Kenya             0
# 4       uniqueid_6073 x Kenya             0
# ...                       ...           ...
# 10081  uniqueid_2998 x Uganda             0
# 10082  uniqueid_2999 x Uganda             0
# 10083  uniqueid_3000 x Uganda             0
# 10084  uniqueid_3001 x Uganda             0
# 10085  uniqueid_3002 x Uganda             0
#
# [10086 rows x 2 columns]

# %%
# Créer un fichier csv pour les resultat
df_result.to_csv('resuktFile.csv', index = False)
